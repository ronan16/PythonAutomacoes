# %% [markdown]
# # Automação "Deixar de Seguir" do Twitter usando Selenium

# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import getpass # < -- IMPORT THIS
#Localizar posição X - Y da tela
import time





def loginUser():
    # Open your browser, and point it to the login page
    someVariable = getpass.getpass("Após login, pressione ENTER nesta msg") #< THIS IS THE SECOND PART
    #Here is where you put the rest of the code you want to execute



#https://twitter.com/anacletolopes
navegador = webdriver.Firefox()
navegador.get('https://twitter.com/')

#Passo 1:  Pegar o XPath do botão "ENTRAR":
# //*[@id="react-root"]/div/div/div[2]/main/div/div/div[1]/div[1]/div/div[3]/div[5]/a/div
navegador.find_element(By.XPATH, 
    '//*[@id="react-root"]/div/div/div[2]/main/div/div/div[1]/div[1]/div/div[3]/div[5]/a/div').click()


#Passo 2: Usuario faz login (evitar problemas com o Twitter) depois volta no código e da ENTER PARA CONTINUAR
loginUser()
#Passo 3: acessa a página de Seguidores e começa a "desseguir"
navegador.get('https://twitter.com/anacletolopes/followings')

removidos = 0

for j in range(80):
    time.sleep(5)
    print("Foram removidos {} pessoas".format(removidos))
    for i in range (10):
        xpath = '/html/body/div[1]/div/div/div[2]/main/div/div/div/div[1]/div/div[2]/section/div/div/div[{}]/div/div/div/div[2]/div[1]/div[2]/div'.format(i+1)
        try:
            navegador.find_element(By.XPATH, xpath).click()
            navegador.find_element(By.XPATH, 
            '/html/body/div[1]/div/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[2]/div[2]/div[1]/div/span/span').click()
        except:
            print("elemento não encontrando, tentando novamente")
    removidos +=10
    navegador.refresh()
# Out:
# Após login, pressione ENTER nesta msg········
# Foram removidos 0 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 10 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 20 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 30 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 40 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 50 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 60 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 70 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 80 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 90 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 100 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 110 pessoas
# elemento não encontrando, tentando novamente
# Foram removidos 120 pessoas
# ...
